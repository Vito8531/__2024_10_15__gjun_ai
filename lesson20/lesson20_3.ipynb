# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.DataFrame(np.random.randn(10,4).cumsum(axis=0),
             columns=['A', 'B', 'C', 'D'],
             index=np.arange(0,100,10)
             )
df.plot.line()
# Out:
# <Axes: >

# %%
fig, axes = plt.subplots(2, 1)
series = pd.Series(np.random.rand(16),
          index=list('abcdefghijklmnop'))
series.plot.bar(ax=axes[0], color='k', alpha=0.7)
series.plot.barh(ax=axes[1], color='k', alpha=0.7)
# Out:
# <Axes: >

# %%
df = pd.DataFrame(np.random.rand(6,4),
             index=['one','two','three','four','five','six'],
             columns=pd.Index(['A', 'B', 'C', 'D'],name='Genus'))
df
# Out:
# Genus         A         B         C         D
# one    0.052565  0.708836  0.614990  0.152269
# two    0.645548  0.637261  0.181827  0.892189
# three  0.856533  0.868785  0.098372  0.346374
# four   0.117999  0.926332  0.519841  0.164216
# five   0.736229  0.313967  0.613756  0.044858
# six    0.912278  0.511603  0.617515  0.221274

# %%
df.plot.bar()
# Out:
# <Axes: >

# %%
df.plot.barh(stacked=True, alpha=0.5)
# Out:
# <Axes: >

# %%
tips = pd.read_csv('tips.csv')
party_counts = pd.crosstab(tips['day'],tips['size'])
party_counts1 = party_counts.loc[:,2:5]
party_pcts = party_counts1.div(party_counts.sum(axis=1),axis=0)
party_pcts
# Out:
# size         2         3         4         5
# day
# Fri   0.842105  0.052632  0.052632  0.000000
# Sat   0.609195  0.206897  0.149425  0.011494
# Sun   0.513158  0.197368  0.236842  0.039474
# Thur  0.774194  0.064516  0.080645  0.016129

# %%
party_pcts.plot.bar()
# Out:
# <Axes: xlabel='day'>
