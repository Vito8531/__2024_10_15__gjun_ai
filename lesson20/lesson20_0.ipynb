# %%
import matplotlib.pyplot as plt
import numpy as np

figure = plt.figure() #top function
axes = figure.add_subplot()#figure 實體內的method()
data = np.arange(10,20)
axes.plot(data)
plt.show()

# %%
data = np.arange(10,20)
plt.plot(data) #使用top function繪圖

# %%
import numpy as np
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
#plt.plot(np.random.randn(50).cumsum(),'k--')
ax1.hist(np.random.randn(100),bins=20,color='k',alpha=0.3)
ax2.scatter(np.arange(30),np.arange(30)+(3 * np.random.randn(30)))
ax3.plot(np.random.randn(50).cumsum(),'k--')
np.random.randn(10)
# Out:
# array([-0.01836508,  1.64254609, -0.2580165 , -1.45239111,  0.23365549,
#         1.23415644,  0.05481714,  1.00038607, -2.15074523, -0.0691574 ])

# %%
#同時建立figure,axes
#top funciton -> subplots
fig, axes = plt.subplots(2,2,sharex=True,sharey=True)
for i in range(2):
    for j in range(2):
        axes[i,j].hist(np.random.randn(500), bins=50, color='k', alpha=0.5)
fig.subplots_adjust(wspace=0,hspace=0)
print(axes)
# Out:
# [[<Axes: > <Axes: >]
#  [<Axes: > <Axes: >]]

# %%
data = np.random.randn(30).cumsum()
plt.plot(data,'k--',label='Default')
plt.plot(data,'k-',drawstyle='steps-post',label='steps-post')
plt.legend(loc='best')
